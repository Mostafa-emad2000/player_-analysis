# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fb = pd.read_csv("players_20.csv")

# %%
top_overall = fb.sort_values(by="overall",ascending=False).head(5)
print(top_overall)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
print (top_overall)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# ...

# %%
top_overall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 4.1+ KB

# %%
top_overall.describe(include="all")
# Out:
#             sofifa_id                                         player_url  \
# count        5.000000                                                  5
# unique            NaN                                                  5
# top               NaN  https://sofifa.com/player/158023/lionel-messi/...
# freq              NaN                                                  1
# mean    150672.200000                                                NaN
# std      74282.130349                                                NaN
# min      20801.000000                                                NaN
# 25%     158023.000000                                                NaN
# 50%     183277.000000                                                NaN
# 75%     190871.000000                                                NaN
# max     200389.000000                                                NaN
#
#        short_name                       long_name        age         dob  \
# ...

# %%
player_information = ["attacking_finishing","attacking_short_passing","power_shot_power","power_long_shots","skill_long_passing","mentality_interceptions",
                      "mentality_vision","passing","skill_dribbling","dribbling","skill_long_passing","pace","power_strength","power_stamina",
                      "physic","movement_reactions","skill_moves","short_name"]

# %%
top_overall.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
print (player_information)
# Out:
# ['attacking_finishing', 'attacking_short_passing', 'power_shot_power', 'power_long_shots', 'skill_long_passing', 'mentality_interceptions', 'mentality_vision', 'passing', 'skill_dribbling', 'dribbling', 'skill_long_passing', 'pace', 'power_strength', 'power_stamina', 'physic', 'movement_reactions', 'skill_moves', 'short_name']

# %%
df = pd.DataFrame(top_overall)
date_player = df[player_information]
print (date_player)
# Out:
#    attacking_finishing  attacking_short_passing  power_shot_power  \
# 0                   95                       92                86
# 1                   94                       83                95
# 2                   87                       87                80
# 3                   11                       43                59
# 4                   84                       89                82
#
#    power_long_shots  skill_long_passing  mentality_interceptions  \
# 0                94                  92                       40
# 1                93                  77                       29
# 2                84                  81                       36
# 3                12                  40                       19
# 4                80                  83                       41
#
#    mentality_vision  passing  skill_dribbling  dribbling  skill_long_passing  \
# 0                94     92.0               97       96.0                  92
# ...

# %%
print(date_player.isnull().sum())
# Out:
# attacking_finishing        0
# attacking_short_passing    0
# power_shot_power           0
# power_long_shots           0
# skill_long_passing         0
# mentality_interceptions    0
# mentality_vision           0
# passing                    1
# skill_dribbling            0
# dribbling                  1
# skill_long_passing         0
# pace                       1
# power_strength             0
# power_stamina              0
# physic                     1
# movement_reactions         0
# skill_moves                0
# short_name                 0
# dtype: int64

# %%
date_player["passing"].fillna(date_player["passing"].median(), inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\586634666.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   date_player["passing"].fillna(date_player["passing"].median(), inplace = True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\586634666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
date_player["dribbling"].fillna(date_player["dribbling"].median(), inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\1945753452.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   date_player["dribbling"].fillna(date_player["dribbling"].median(), inplace = True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\1945753452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
date_player["pace"].fillna(date_player["pace"].median(), inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\3472651619.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   date_player["pace"].fillna(date_player["pace"].median(), inplace = True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\3472651619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
date_player["physic"].fillna(date_player["physic"].median(), inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\1014406333.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   date_player["physic"].fillna(date_player["physic"].median(), inplace = True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21172\1014406333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
print(date_player.isnull().sum())
# Out:
# attacking_finishing        0
# attacking_short_passing    0
# power_shot_power           0
# power_long_shots           0
# skill_long_passing         0
# mentality_interceptions    0
# mentality_vision           0
# passing                    0
# skill_dribbling            0
# dribbling                  0
# skill_long_passing         0
# pace                       0
# power_strength             0
# power_stamina              0
# physic                     0
# movement_reactions         0
# skill_moves                0
# short_name                 0
# dtype: int64

# %%
date_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 4
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   attacking_finishing      5 non-null      int64
#  1   attacking_short_passing  5 non-null      int64
#  2   power_shot_power         5 non-null      int64
#  3   power_long_shots         5 non-null      int64
#  4   skill_long_passing       5 non-null      int64
#  5   mentality_interceptions  5 non-null      int64
#  6   mentality_vision         5 non-null      int64
#  7   passing                  5 non-null      float64
#  8   skill_dribbling          5 non-null      int64
#  9   dribbling                5 non-null      float64
#  10  skill_long_passing       5 non-null      int64
#  11  pace                     5 non-null      float64
#  12  power_strength           5 non-null      int64
#  13  power_stamina            5 non-null      int64
# ...

# %%
date_player.describe(include="all")
# Out:
#         attacking_finishing  attacking_short_passing  power_shot_power  \
# count               5.00000                 5.000000          5.000000
# unique                  NaN                      NaN               NaN
# top                     NaN                      NaN               NaN
# freq                    NaN                      NaN               NaN
# mean               74.20000                78.800000         80.400000
# std                35.63285                20.278067         13.277801
# min                11.00000                43.000000         59.000000
# 25%                84.00000                83.000000         80.000000
# 50%                87.00000                87.000000         82.000000
# 75%                94.00000                89.000000         86.000000
# max                95.00000                92.000000         95.000000
#
#         power_long_shots  skill_long_passing  mentality_interceptions  \
# ...

# %%
date_player.shape
# Out:
# (5, 18)

# %%
date_player.to_excel("output.xlsx",index=False)
